# %%
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.ui import Console

# %%
model = OpenAIChatCompletionClient(model="gpt-5-nano")

clarity_agent = AssistantAgent(
    "CliarityAgent",
    model_client=model,
    system_message="""You are an expert editor focused on clarity and simplicity. 
            Your job is to eliminate ambiguity, redundancy, and make every sentence crisp and clear. 
            Don't worry about persuasion or tone — just make the message easy to read and understand.""",
)

tone_agent = AssistantAgent(
    "ToneAgent",
    model_client=model,
    system_message="""You are a communication coach focused on emotional tone and professionalism. 
            Your job is to make the email sound warm, confident, and human — while staying professional 
            and appropriate for the audience. Improve the emotional resonance, polish the phrasing, 
            and adjust any words that may come off as stiff, cold, or overly casual.""",
)

persuasion_agent = AssistantAgent(
    "PersuasionAgent",
    model_client=model,
    system_message="""You are a persuasion expert trained in marketing, behavioral psychology, 
            and copywriting. Your job is to enhance the email's persuasive power: improve call to action, structure arguments, and emphasize benefits. Remove weak or passive language.""",
)

synthesizer_agent = AssistantAgent(
    "SynthesizerAgent",
    model_client=model,
    system_message="""You are an advanced email-writing specialist. Your role is to read all 
            prior agent responses and revisions, and then **synthesize the best ideas** into a unified, 
            polished draft of the email. Focus on: Integrating clarity, tone, and persuasion improvements; 
            Ensuring coherence, fluency, and a natural voice; Creating a version that feels professional, 
            effective, and readable.""",
)

critic_agent = AssistantAgent(
    "CriticAgent",
    model_client=model,
    system_message="""You are an email quality evaluator. Your job is to perform a final review 
            of the synthesized email and determine if it meets professional standards. Review the email for: 
            Clarity and flow, appropriate professional tone, effective call-to-action, and overall coherence.
            Be constructive but decisive. If the email has major flaws (unclear message, unprofessional tone, 
            or missing key elements), provide ONE specific improvement suggestion. If the email meets professional standards and communicates effectively, respond with 'The email meets professional standards.' followed by `TERMINATE` on a new line. You should only approve emails that are perfect enough for professional use, dont settle.""",
)

# %%
text_termination = TextMentionTermination("TERMINATE")
max_messages_termination = MaxMessageTermination(max_messages=30)

termination_condition = text_termination | max_messages_termination

# %%
team = RoundRobinGroupChat(
    participants=[
        clarity_agent,
        tone_agent,
        persuasion_agent,
        synthesizer_agent,
        critic_agent,
    ],
    termination_condition=termination_condition,
)

# awyncronous python
await Console(
    team.run_stream(
        task="공항까지 태워다 줘, 그리고 내 휴가에 쓸 돈을 빌려줘. 준비되면 알려줘."
    )
)
# Out:
# ---------- TextMessage (user) ----------
# 공항까지 태워다 줘, 그리고 내 휴가에 쓸 돈을 빌려줘. 준비되면 알려줘.
# ---------- TextMessage (CliarityAgent) ----------
# 도와드리고 싶지만, 저는 직접 데려다 주거나 돈을 빌려줄 수는 없어요. 대신 아래처럼 도와드릴 수 있습니다.
#
# 무엇을 도와드릴까 선택해 주세요
# - 공항까지 가는 최적 이동 방법 계산: 출발지와 공항 이름을 알려주시면 가장 빠른 경로와 예상 시간/비용을 알려드려요.
# - 휴가 자금 계획 도와주기: 예산표 작성, 비용 절약 팁, 단기 자금 확보 방법 안내를 해드려요.
# - 요청 메시지 초안 작성: 친구/가족에게 태워 달라거나 빌려 달라고 요청하는 메시지 초안을 깔끔한 문장으로 만들어 드립니다.
#
# 원하시면 바로 시작할 수 있도록 아래 정보를 알려주세요
# - 출발지와 도착하는 공항
# - 원하시는 출발 시간대
# - 여행 예산(선택적)
# - 돈이 필요하다면 빌려 달라는 대상과 상황에 대한 간단한 맥락
#
# 참고용 초안 예시
# - 탑승 요청 메시지(친구/지인에게)
#   "안녕 [이름], 오늘 공항까지 태워다 줄 수 있을까? [시간]에 만나면 될 것 같아. 가능하면 알려줘. 고마워!"
#
# - 도움 요청 메시지(돈 빌려 달라기)
#   "안녕하세요 [이름], 이번 휴가 경비로 조금 부족해서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을지요? 가능 여부를 알려주시면 감사하겠습니다. 불편하시면 거절해주셔도 됩니다."
#
# 필요한 정보를 주시면 바로 준비해 드리겠습니다.
# ---------- TextMessage (ToneAgent) ----------
# 도와드리겠습니다. 다만 직접 차를 태워주거나 돈을 빌려주는 건 어렵습니다. 대신 더 매끄럽고 따뜻하게 다가갈 수 있도록 아래와 같이 도와드릴 수 있어요.
#
# 무엇을 도와드릴까요? 선택해 주세요
# - 공항까지 가는 최적 이동 방법 계산: 출발지와 공항 이름을 알려주시면 가장 빠른 경로와 예상 시간/비용을 알려드려요.
# - 휴가 자금 계획 도와드리기: 예산표 작성, 비용 절약 팁, 단기 자금 확보 방법 등을 함께 정리해 드립니다.
# - 요청 메시지 초안 작성: 친구/가족에게 태워 달라거나 빌려 달라고 요청하는 메시지를 깔끔하고 자연스럽게 다듬어 드립니다.
#
# 바로 시작하도록 필요한 정보 소개
# - 출발지와 도착하는 공항
# - 원하시는 출발 시간대
# - 여행 예산(선택)
# - 돈이 필요하다면 빌려 달라는 대상과 상황에 대한 간단한 맥락
#
# 참고용 초안 예시 (다듬은 버전)
# - 탑승 요청 메시지(친구/지인에게)
#   "안녕 [이름], 오늘 공항까지 태워다 줄 수 있을까? [시간]에 만나면 될 것 같아. 가능하면 알려줘. 고마워!"
#
# - 도움 요청 메시지(돈 빌려 달라기)
#   "안녕하세요 [이름], 이번 휴가 경비가 조금 부족해서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을지요? 가능 여부를 알려주시면 감사하겠습니다. 불편하시면 거절하셔도 됩니다."
#
# 상황에 맞춘 톤 제안
# - 친구/가족에게 보내는 경우: 더 따뜻하고 자연스러운 말투로, 간단한 인사와 감사의 표현을 포함합니다.
# - 동료나 모르는 지인에게 보내는 경우: 약간 더 정중하고 간결한 톤으로, 필요한 정보만 명확하게 요청합니다.
#
# 원하시면 지금 바로 맞춤 초안을 만들어 드릴게요. 상황과 대상에 대해 몇 가지를 알려주시면 바로 시작하겠습니다.
# ---------- TextMessage (PersuasionAgent) ----------
# 멋져요. 요청의 목표를 더 선명하게 하고, 바로 행동으로 이끌 수 있도록 강하고 명확한 초안으로 다듬어 드릴게요. 상황에 맞게 골라 사용하거나 그대로 복사해 쓰셔도 됩니다.
#
# 1) 탑승 요청 메시지: 친구/가족에게
# - 버전 A(따뜻하고 상세):
#   안녕 [이름]! 이번 주 [날짜] [시간]에 공항까지 태워다 줄 수 있을까? [출발지]에서 만나서 [도착 공항]으로 같이 가면 될 것 같아. 가능하면 바로 알려줘줘. 네가 도와주면 정말 큰 도움이 되고, 주유비와 주차비는 내가 전액 부담할게. 고마워!
#
# - 버전 B(간결하고 확실):
#   안녕 [이름], [날짜] [시간]에 공항까지 태워다 줄 수 있어? [출발지]에서 바로 만나서 [도착 공항]으로 갈게. 가능하면 바로 알려줘. 비용은 내가 전부 부담할게.
#
# - 버전 C(격식 있는 톤):
#   안녕하세요 [이름], 다름이 아니라 [날짜] [시간]에 공항까지 태워주실 수 있을지 여쭙습니다. [출발지]에서 모여 [공항]으로 이동하면 될 것 같습니다. 가능하시면 알려주시면 감사하겠습니다. 주유비와 주차비는 전액 제가 부담하겠습니다.
#
# 2) 탑승 요청 메시지: 동료/지인/모르는 사람에게
# - 버전 A(직설적이고 프로페셔널):
#   안녕하세요 [이름], [날짜] [시간]에 공항까지 태워다 주실 수 있을까요? [출발지]에서 [공항]으로 바로 연결되도록 도와주시면 감사합니다. 가능하시면 바로 회신 부탁드립니다. 주유비는 제가 모두 부담하겠습니다.
#
# - 버전 B(짧고 명확):
#   안녕하세요 [이름], [날짜] [시간]에 공항까지 태워주실 수 있을까요? 비용은 제가 부담합니다. 가능하신지 바로 알려주시면 감사하겠습니다.
#
# 3) 휴가 자금 지원 요청 메시지: 친구/가족에게
# - 버전 A(정중하고 설득력 있게):
#   안녕하세요 [이름], 이번 휴가 경비가 예상보다 조금 더 들어서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을지 여쭙습니다. 가능 여부를 알려주시면 정말 감사하겠습니다. 부담되시면 거절해도 괜찮습니다.
#
# - 버전 B(간결하고 직접):
#   안녕하세요 [이름], 휴가 경비를 조금 보태야 해서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을까요? 가능 여부만 알려주시면 감사하겠습니다.
#
# - 버전 C(확인 가능한 약속 포함):
#   안녕하세요 [이름], 이번 휴가 경비가 예상보다 늘어나 [금액]원이 필요합니다. [기간] 이내에 상환하겠다는 조건으로 빌려주실 수 있으면 정말 감사하겠습니다. 거절해도 전혀 불편해하지 않아요. 가능 여부를 알려주실 수 있을까요?
#
# 4) 상황별 톤 제안(간단 가이드)
# - 친구/가족에게 보내는 경우: 따뜻하고 자연스러운 말투로, 인사와 감사 표현을 포함합니다. 가능하면 구체 시간과 장소를 명시해 주세요.
# - 동료나 모르는 지인에게 보내는 경우: 약간 더 정중하고 간결한 톤으로, 필요한 정보만 분명하게 요청합니다.
# - 금전 요청의 경우: 비난 없이 존중하는 표현으로, 상환 계획을 명확히 제시하거나 “거절해도 괜찮다”는 여지를 남깁니다.
#
# 필요하신 정보를 주시면 바로 맞춤 초안으로 다시 만들어 드리겠습니다. 예: 상대의 이름, 날짜/시간, 출발지와 도착 공항, 빌려주실 금액/상환 기간, 그리고 상황에 맞춘 톤(친구/가족/동료/모르는 지인 중 어떤 쪽인지).
# ---------- TextMessage (SynthesizerAgent) ----------
# 다음은 두 요청을 한 사람에게 보내는 “통합 초안”의 다듬은 버전입니다. 친한 친구/가족에게 보내는 톤으로, 두 가지 요청을 한 메시지에 담아도 자연스럽도록 구성했습니다. 필요에 따라 상대를 바꿔서 두 개의 독립 메시지로도 바로 쓸 수 있습니다.
#
# 통합 초안(친구/가족에게 보내는 버전, 따뜻하고 명확한 톤)
# - 안녕 [이름], 다름이 아니라 두 가지 부탁이 있어 이렇게 연락해.
#   1) [날짜] [시간]에 [출발지]에서 [도착 공항]으로 가는 길에 공항까지 태워다 주실 수 있을까? 가능하면 바로 알려줘. 네 도움 주시면 정말 큰 힘이 되고, 주유비와 주차비는 내가 전액 부담할게.
#   2) 이번 휴가 경비가 조금 더 들 것 같아서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을지 여쭙고 싶어. 부담되면 거절해도 전혀 괜찮아. 가능 여부를 알려주면 정말 고마울 것 같아.
#
# - 필요하신 경우 아래 정보를 채워 주시면 바로 맞춤 버전으로 더 다듬어 드리겠습니다:
#   - 상대의 이름
#   - 날짜, 시간
#   - 출발지와 도착 공항
#   - 빌려줄 금액과 상환 기간
#   - 상대와의 관계(친구/가족 등) 및 원하는 톤
#
# 추가 안내(상황에 맞춘 톤 선택 팁)
# - 친구/가족에게 보내는 경우: 따뜻하고 자연스러운 말투로, 구체적인 시간과 장소를 명시하는 것이 좋습니다.
# - 동료나 모르는 지인에게 보내는 경우: 더 정중하고 간결한 톤으로 필요한 정보만 요청합니다. 아래 예시를 필요하다면 붙여 드리겠습니다.
#
# 선호하신 경우, 상황에 맞춘 별도 버전도 바로 만들어 드립니다
# - 동일한 내용을 유지하되, 더 간결한 버전(동료/지인 대상)
# - 돈 빌려주기 부분을 완전히 독립된 메시지로 분리한 예
# - 돈 빌려주기를 먼저 제안하는 버전 등
#
# 원하는 대상과 상황에 맞춰 바로 사용할 수 있는 최적의 버전을 원하시면 아래 정보를 알려 주세요:
# - 상대의 이름
# - 날짜/시간
# - 출발지와 도착 공항
# - 빌려줄 금액/상환 기간
# - 대상과의 관계(친구/가족/동료/모르는 사람)
#
# 원하시면 지금 바로 맞춤 초안을 만들어 드리겠습니다.
# ---------- TextMessage (CriticAgent) ----------
# The email meets professional standards.
# TERMINATE
# TaskResult(messages=[TextMessage(id='7dcad6e1-f967-4bcc-a6b8-c138289f4cb0', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 9, 21, 9, 23, 55, 503189, tzinfo=datetime.timezone.utc), content='공항까지 태워다 줘, 그리고 내 휴가에 쓸 돈을 빌려줘. 준비되면 알려줘.', type='TextMessage'), TextMessage(id='05f7e58b-d32f-4ce8-98e9-f60ecc2a4699', source='CliarityAgent', models_usage=RequestUsage(prompt_tokens=89, completion_tokens=2439), metadata={}, created_at=datetime.datetime(2025, 9, 21, 9, 24, 9, 9958, tzinfo=datetime.timezone.utc), content='도와드리고 싶지만, 저는 직접 데려다 주거나 돈을 빌려줄 수는 없어요. 대신 아래처럼 도와드릴 수 있습니다.\n\n무엇을 도와드릴까 선택해 주세요\n- 공항까지 가는 최적 이동 방법 계산: 출발지와 공항 이름을 알려주시면 가장 빠른 경로와 예상 시간/비용을 알려드려요.\n- 휴가 자금 계획 도와주기: 예산표 작성, 비용 절약 팁, 단기 자금 확보 방법 안내를 해드려요.\n- 요청 메시지 초안 작성: 친구/가족에게 태워 달라거나 빌려 달라고 요청하는 메시지 초안을 깔끔한 문장으로 만들어 드립니다.\n\n원하시면 바로 시작할 수 있도록 아래 정보를 알려주세요\n- 출발지와 도착하는 공항\n- 원하시는 출발 시간대\n- 여행 예산(선택적)\n- 돈이 필요하다면 빌려 달라는 대상과 상황에 대한 간단한 맥락\n\n참고용 초안 예시\n- 탑승 요청 메시지(친구/지인에게)\n  "안녕 [이름], 오늘 공항까지 태워다 줄 수 있을까? [시간]에 만나면 될 것 같아. 가능하면 알려줘. 고마워!"\n\n- 도움 요청 메시지(돈 빌려 달라기)\n  "안녕하세요 [이름], 이번 휴가 경비로 조금 부족해서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을지요? 가능 여부를 알려주시면 감사하겠습니다. 불편하시면 거절해주셔도 됩니다."\n\n필요한 정보를 주시면 바로 준비해 드리겠습니다.', type='TextMessage'), TextMessage(id='89a5a445-295e-4a57-946c-f8d92c497e31', source='ToneAgent', models_usage=RequestUsage(prompt_tokens=499, completion_tokens=1979), metadata={}, created_at=datetime.datetime(2025, 9, 21, 9, 24, 18, 459131, tzinfo=datetime.timezone.utc), content='도와드리겠습니다. 다만 직접 차를 태워주거나 돈을 빌려주는 건 어렵습니다. 대신 더 매끄럽고 따뜻하게 다가갈 수 있도록 아래와 같이 도와드릴 수 있어요.\n\n무엇을 도와드릴까요? 선택해 주세요\n- 공항까지 가는 최적 이동 방법 계산: 출발지와 공항 이름을 알려주시면 가장 빠른 경로와 예상 시간/비용을 알려드려요.\n- 휴가 자금 계획 도와드리기: 예산표 작성, 비용 절약 팁, 단기 자금 확보 방법 등을 함께 정리해 드립니다.\n- 요청 메시지 초안 작성: 친구/가족에게 태워 달라거나 빌려 달라고 요청하는 메시지를 깔끔하고 자연스럽게 다듬어 드립니다.\n\n바로 시작하도록 필요한 정보 소개\n- 출발지와 도착하는 공항\n- 원하시는 출발 시간대\n- 여행 예산(선택)\n- 돈이 필요하다면 빌려 달라는 대상과 상황에 대한 간단한 맥락\n\n참고용 초안 예시 (다듬은 버전)\n- 탑승 요청 메시지(친구/지인에게)\n  "안녕 [이름], 오늘 공항까지 태워다 줄 수 있을까? [시간]에 만나면 될 것 같아. 가능하면 알려줘. 고마워!"\n\n- 도움 요청 메시지(돈 빌려 달라기)\n  "안녕하세요 [이름], 이번 휴가 경비가 조금 부족해서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을지요? 가능 여부를 알려주시면 감사하겠습니다. 불편하시면 거절하셔도 됩니다."\n\n상황에 맞춘 톤 제안\n- 친구/가족에게 보내는 경우: 더 따뜻하고 자연스러운 말투로, 간단한 인사와 감사의 표현을 포함합니다.\n- 동료나 모르는 지인에게 보내는 경우: 약간 더 정중하고 간결한 톤으로, 필요한 정보만 명확하게 요청합니다.\n\n원하시면 지금 바로 맞춤 초안을 만들어 드릴게요. 상황과 대상에 대해 몇 가지를 알려주시면 바로 시작하겠습니다.', type='TextMessage'), TextMessage(id='6a42f075-f8d7-40b8-86a8-4476946c24db', source='PersuasionAgent', models_usage=RequestUsage(prompt_tokens=982, completion_tokens=4287), metadata={}, created_at=datetime.datetime(2025, 9, 21, 9, 24, 36, 582482, tzinfo=datetime.timezone.utc), content='멋져요. 요청의 목표를 더 선명하게 하고, 바로 행동으로 이끌 수 있도록 강하고 명확한 초안으로 다듬어 드릴게요. 상황에 맞게 골라 사용하거나 그대로 복사해 쓰셔도 됩니다.\n\n1) 탑승 요청 메시지: 친구/가족에게\n- 버전 A(따뜻하고 상세):\n  안녕 [이름]! 이번 주 [날짜] [시간]에 공항까지 태워다 줄 수 있을까? [출발지]에서 만나서 [도착 공항]으로 같이 가면 될 것 같아. 가능하면 바로 알려줘줘. 네가 도와주면 정말 큰 도움이 되고, 주유비와 주차비는 내가 전액 부담할게. 고마워!\n\n- 버전 B(간결하고 확실):\n  안녕 [이름], [날짜] [시간]에 공항까지 태워다 줄 수 있어? [출발지]에서 바로 만나서 [도착 공항]으로 갈게. 가능하면 바로 알려줘. 비용은 내가 전부 부담할게.\n\n- 버전 C(격식 있는 톤):\n  안녕하세요 [이름], 다름이 아니라 [날짜] [시간]에 공항까지 태워주실 수 있을지 여쭙습니다. [출발지]에서 모여 [공항]으로 이동하면 될 것 같습니다. 가능하시면 알려주시면 감사하겠습니다. 주유비와 주차비는 전액 제가 부담하겠습니다.\n\n2) 탑승 요청 메시지: 동료/지인/모르는 사람에게\n- 버전 A(직설적이고 프로페셔널):\n  안녕하세요 [이름], [날짜] [시간]에 공항까지 태워다 주실 수 있을까요? [출발지]에서 [공항]으로 바로 연결되도록 도와주시면 감사합니다. 가능하시면 바로 회신 부탁드립니다. 주유비는 제가 모두 부담하겠습니다.\n\n- 버전 B(짧고 명확):\n  안녕하세요 [이름], [날짜] [시간]에 공항까지 태워주실 수 있을까요? 비용은 제가 부담합니다. 가능하신지 바로 알려주시면 감사하겠습니다.\n\n3) 휴가 자금 지원 요청 메시지: 친구/가족에게\n- 버전 A(정중하고 설득력 있게):\n  안녕하세요 [이름], 이번 휴가 경비가 예상보다 조금 더 들어서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을지 여쭙습니다. 가능 여부를 알려주시면 정말 감사하겠습니다. 부담되시면 거절해도 괜찮습니다.\n\n- 버전 B(간결하고 직접):\n  안녕하세요 [이름], 휴가 경비를 조금 보태야 해서 [금액]원을 [기간] 이내에 상환하는 조건으로 빌려주실 수 있을까요? 가능 여부만 알려주시면 감사하겠습니다.\n\n- 버전 C(확인 가능한 약속 포함):\n  안녕하세요 [이름], 이번 휴가 경비가 예상보다 늘어나 [금액]원이 필요합니다. [기간] 이내에 상환하겠다는 조건으로 빌려주실 수 있으면 정말 감사하겠습니다. 거절해도 전혀 불편해하지 않아요. 가능 여부를 알려주실 수 있을까요?\n\n4) 상황별 톤 제안(간단 가이드)\n- 친구/가족에게 보내는 경우: 따뜻하고 자연스러운 말투로, 인사와 ...
